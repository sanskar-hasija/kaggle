# %% [markdown]
# **Created by Sanskar Hasija**
#
# **TOP 50 Cryptocurrencies Historical Prices: Starter**
#
# **26 August 2021**

# %% [markdown]
# # <center> TOP 50 Cryptocurrencies Historical Prices: Starter </center>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %% [markdown]
# # Analysis of a single cryptocurrency

# %% [markdown]
# **The analysis is done for each day starting from January  2020 to July 2021 on Ethereum (ETH) cryptocurrency.**

# %%
eth_data = pd.read_csv("../input/top-50-cryptocurrency-historical-prices/Ethereum.csv" , 
                       index_col =["SNo"] , 
                       parse_dates=['Date'])
start = "2020-01-01"
end = "2021-07-31"
mask = (eth_data['Date'] >= start) & (eth_data['Date'] <= end)
eth_data = eth_data.loc[mask]
eth_data.head()
# Out:
#            Date   Price    Open    High     Low        Vol.  Change %
# SNo
# 1393 2020-01-01  130.75  129.21  132.97  128.81  10350000.0      1.19
# 1394 2020-01-02  127.19  130.75  130.77  126.74  11450000.0     -2.72
# 1395 2020-01-03  134.27  127.19  134.86  126.05  15670000.0      5.56
# 1396 2020-01-04  134.33  134.30  135.57  132.76  11160000.0      0.04
# 1397 2020-01-05  135.59  134.32  138.33  134.32  12190000.0      0.94

# %%
eth_data.describe()
# Out:
#              Price         Open         High          Low          Vol.  \
# count   578.000000   578.000000   578.000000   578.000000  5.780000e+02
# mean    957.002232   952.915138   993.800657   907.547145  9.671973e+06
# std     946.802979   945.214490   990.523292   892.483292  9.778743e+06
# min     107.900000   107.870000   117.910000    88.500000  2.703000e+04
# 25%     230.765000   229.970000   234.585000   225.170000  2.072500e+06
# 50%     399.795000   397.790000   410.290000   385.830000  6.675000e+06
# 75%    1785.482500  1783.045000  1839.027500  1714.827500  1.394000e+07
# max    4167.780000  4173.610000  4366.100000  3794.150000  6.070000e+07
#
#          Change %
# count  578.000000
# mean     0.682491
# std      5.653414
# min    -44.550000
# 25%     -1.950000
# 50%      0.655000
# 75%      3.430000
# max     25.960000

# %% [markdown]
# ## Area Chart for daily prices

# %%
area = px.area(data_frame = eth_data ,
               y = "Price",
               x="Date", 
               title = 'Ethereum(ETH) Daily Price')

area.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

area.update_yaxes(title_text = 'Price in USD', ticksuffix = '$')
area.update_layout(showlegend = True,
    title = {
        'text': 'Ethereum(ETH) Daily Price (2020-Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

area.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7b5b6179-d88c-40fd-86b9-f356861208cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b5b6179-d88c-40fd-86b9-f356861208cd")) {                    Plotly.newPlot(                        "7b5b6179-d88c-40fd-86b9-f356861208cd",                        [{"hovertemplate":"Date=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","type":"scatter","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-2 ...

# %% [markdown]
# ## Candlestick Chart

# %%
candlestick = go.Figure(data = [go.Candlestick(x =eth_data["Date"], 
                                               open = eth_data[('Open')], 
                                               high = eth_data[('High')], 
                                               low = eth_data[('Low')], 
                                               close = eth_data[('Price')])])
candlestick.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

candlestick.update_layout(
    title = {
        'text': 'Ethereum(ETH) Daily Price(2019-Present) Candelstick Chart',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

candlestick.update_yaxes(title_text = 'Price in USD', ticksuffix = '$')
candlestick.show()
# Out:
# <div>                            <div id="6137fa22-5a18-4835-884f-1749c515d129" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6137fa22-5a18-4835-884f-1749c515d129")) {                    Plotly.newPlot(                        "6137fa22-5a18-4835-884f-1749c515d129",                        [{"close":[130.75,127.19,134.27,134.33,135.59,144.08,143.04,140.81,137.92,144.81,142.67,146.46,143.6,166.07,166.45,164.36,170.22,174.19,166.92,166.87,169.41,168.13,162.8,162.55,160.44,167.9,170.27,175.74,173.86,184.59,179.91,183.64,188.5,189.79,188.93,203.83,213.16,223.51,223.23,228.59,222.95,236.76,265.58,268.75,285.25,264.87,259.99,267.63,282.26,259.12,257.39,265.11,261.64,274.72,265.65,246.96,224.3,227.53,226.93,217.52,217.99,231.87,223.94,224.38,228.45,244.9,237.32,199.16,202.85,200.56,194.58,107.9,133.99,122.69,124.35,111.02,116.06,117.77,135.43,133.32,132.58,122.41,136.02,138.62,136.07,138.38,131.74,131.03,125.24,132.15,132.86,135.66,141.3,141.14,144.01,142.58,171.06,164.71,173.0,169.68,157.86,158.18,158.73,156.38,158.45,152.9,172.31,170.63,187.45,180.13,170.4,170.79,182.72,185.46,187.58,194.01,197.35,196.14,196.55,215.4,206.22,212.0,213.96,209.83,206.61,205.36,199.04,212.0,211.45,210.22,187.78,185.96,189.84,199.58,203.3,194.85,200.51,207.0,214.87,214.51,209.99,198.75,207.35,206.62,199.97,204.13,201.0,208.18,220.18,220.66,243.63,231.81,247.97,237.94,244.52,243.37,240.23,242.0,244.56,246.18,243.82,247.78,230.71,237.54,238.22,232.02,230.93,235.36,233.88,231.34,229.11,228.86,228.13,243.25,243.2,234.75,232.56,229.67,221.06,225.09,227.87,225.63,230.95,226.42,225.12,229.15,227.98,241.56,239.25,246.99,242.02,241.26,239.2,242.75,239.73,240.5,238.62,233.65,232.75,235.75,239.01,236.1,245.53,263.28,275.34,279.33,305.32,311.13,321.8,316.96,317.82,334.87,346.51,387.14,372.08,385.8,389.62,400.79,394.83,379.57,396.76,390.23,395.53,379.01,387.12,424.31,438.03,432.18,433.63,430.56,422.16,407.44,416.05,387.99,395.56,390.5,407.7,383.2,385.96,383.11,395.11,398.8,428.86,433.9,475.8,439.08,381.97,385.94,334.91,353.49,352.06,337.46,351.1,367.92,373.72,387.98,365.71,376.7,364.01,364.88,388.97,384.2,385.25,371.12,341.3,344.03,319.95,349.17,351.63,354.25,357.23,354.08,359.86,359.39,353.07,345.68,345.6,352.73,353.28,340.61,341.48,350.83,365.28,370.16,374.19,386.68,381.23,379.15,377.45,365.17,368.63,377.81,379.19,368.35,391.2,414.05,408.52,411.92,406.09,394.11,403.15,388.14,386.76,382.41,386.42,396.29,383.53,387.92,402.19,416.63,455.72,435.4,454.68,444.33,450.22,463.33,462.56,476.29,460.7,448.23,460.43,481.95,478.52,471.21,509.98,551.91,559.4,609.22,605.03,569.67,519.32,518.11,537.74,575.45,615.92,585.66,598.05,616.32,567.91,596.68,601.68,591.09,555.05,573.21,558.13,544.17,567.78,591.09,586.19,588.91,637.38,643.17,653.85,658.17,638.26,607.85,637.47,585.69,612.34,626.93,636.58,683.71,730.05,731.76,751.8,735.94,729.12,774.5,974.97,1042.4,1099.52,1207.77,1224.35,1215.73,1275.58,1256.04,1091.47,1050.19,1128.46,1226.17,1171.68,1228.27,1232.64,1258.06,1372.0,1377.53,1117.33,1234.58,1233.4,1390.28,1317.9,1366.27,1247.62,1328.47,1379.3,1376.96,1312.73,1373.4,1511.36,1664.34,1594.0,1719.2,1676.63,1612.99,1750.18,1770.63,1742.09,1786.35,1841.02,1815.49,1801.78,1778.82,1781.69,1847.95,1934.16,1955.59,1913.88,1933.45,1777.28,1578.11,1623.71,1476.15,1445.44,1458.93,1418.76,1570.03,1488.62,1571.05,1538.61,1530.29,1649.19,1728.1,1831.49,1869.1,1794.14,1825.79,1766.9,1921.13,1849.06,1792.38,1804.85,1823.35,1776.08,1809.64,1804.6,1783.72,1682.37,1667.9,1582.38,1586.54,1698.6,1713.01,1686.8,1816.69,1841.01,1917.99,1967.96,2134.55,2008.59,2075.94,2106.41,2111.53,1961.46,2079.92,2066.93,2133.79,2151.42,2137.81,2299.93,2431.56,2514.22,2423.18,2318.33,2237.17,2160.63,2332.14,2360.81,2401.1,2367.31,2215.93,2316.48,2533.12,2665.24,2746.54,2757.36,2772. ...

# %% [markdown]
# ## OHLC Chart

# %%
ohlc = go.Figure(data = [go.Ohlc(x = eth_data["Date"], 
                                               open = eth_data[('Open')], 
                                               high = eth_data[('High')], 
                                               low = eth_data[('Low')], 
                                               close = eth_data[('Price')])])

ohlc.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

ohlc.update_layout(
    title = {
        'text': 'Ethereum(ETH) Daily Price(2020-Present) OHLC Chart',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
ohlc.update_yaxes(title_text = 'Price in USD', ticksuffix = '$')
ohlc.show()
# Out:
# <div>                            <div id="ad4f90c4-068e-4f7c-a672-19187292aca9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad4f90c4-068e-4f7c-a672-19187292aca9")) {                    Plotly.newPlot(                        "ad4f90c4-068e-4f7c-a672-19187292aca9",                        [{"close":[130.75,127.19,134.27,134.33,135.59,144.08,143.04,140.81,137.92,144.81,142.67,146.46,143.6,166.07,166.45,164.36,170.22,174.19,166.92,166.87,169.41,168.13,162.8,162.55,160.44,167.9,170.27,175.74,173.86,184.59,179.91,183.64,188.5,189.79,188.93,203.83,213.16,223.51,223.23,228.59,222.95,236.76,265.58,268.75,285.25,264.87,259.99,267.63,282.26,259.12,257.39,265.11,261.64,274.72,265.65,246.96,224.3,227.53,226.93,217.52,217.99,231.87,223.94,224.38,228.45,244.9,237.32,199.16,202.85,200.56,194.58,107.9,133.99,122.69,124.35,111.02,116.06,117.77,135.43,133.32,132.58,122.41,136.02,138.62,136.07,138.38,131.74,131.03,125.24,132.15,132.86,135.66,141.3,141.14,144.01,142.58,171.06,164.71,173.0,169.68,157.86,158.18,158.73,156.38,158.45,152.9,172.31,170.63,187.45,180.13,170.4,170.79,182.72,185.46,187.58,194.01,197.35,196.14,196.55,215.4,206.22,212.0,213.96,209.83,206.61,205.36,199.04,212.0,211.45,210.22,187.78,185.96,189.84,199.58,203.3,194.85,200.51,207.0,214.87,214.51,209.99,198.75,207.35,206.62,199.97,204.13,201.0,208.18,220.18,220.66,243.63,231.81,247.97,237.94,244.52,243.37,240.23,242.0,244.56,246.18,243.82,247.78,230.71,237.54,238.22,232.02,230.93,235.36,233.88,231.34,229.11,228.86,228.13,243.25,243.2,234.75,232.56,229.67,221.06,225.09,227.87,225.63,230.95,226.42,225.12,229.15,227.98,241.56,239.25,246.99,242.02,241.26,239.2,242.75,239.73,240.5,238.62,233.65,232.75,235.75,239.01,236.1,245.53,263.28,275.34,279.33,305.32,311.13,321.8,316.96,317.82,334.87,346.51,387.14,372.08,385.8,389.62,400.79,394.83,379.57,396.76,390.23,395.53,379.01,387.12,424.31,438.03,432.18,433.63,430.56,422.16,407.44,416.05,387.99,395.56,390.5,407.7,383.2,385.96,383.11,395.11,398.8,428.86,433.9,475.8,439.08,381.97,385.94,334.91,353.49,352.06,337.46,351.1,367.92,373.72,387.98,365.71,376.7,364.01,364.88,388.97,384.2,385.25,371.12,341.3,344.03,319.95,349.17,351.63,354.25,357.23,354.08,359.86,359.39,353.07,345.68,345.6,352.73,353.28,340.61,341.48,350.83,365.28,370.16,374.19,386.68,381.23,379.15,377.45,365.17,368.63,377.81,379.19,368.35,391.2,414.05,408.52,411.92,406.09,394.11,403.15,388.14,386.76,382.41,386.42,396.29,383.53,387.92,402.19,416.63,455.72,435.4,454.68,444.33,450.22,463.33,462.56,476.29,460.7,448.23,460.43,481.95,478.52,471.21,509.98,551.91,559.4,609.22,605.03,569.67,519.32,518.11,537.74,575.45,615.92,585.66,598.05,616.32,567.91,596.68,601.68,591.09,555.05,573.21,558.13,544.17,567.78,591.09,586.19,588.91,637.38,643.17,653.85,658.17,638.26,607.85,637.47,585.69,612.34,626.93,636.58,683.71,730.05,731.76,751.8,735.94,729.12,774.5,974.97,1042.4,1099.52,1207.77,1224.35,1215.73,1275.58,1256.04,1091.47,1050.19,1128.46,1226.17,1171.68,1228.27,1232.64,1258.06,1372.0,1377.53,1117.33,1234.58,1233.4,1390.28,1317.9,1366.27,1247.62,1328.47,1379.3,1376.96,1312.73,1373.4,1511.36,1664.34,1594.0,1719.2,1676.63,1612.99,1750.18,1770.63,1742.09,1786.35,1841.02,1815.49,1801.78,1778.82,1781.69,1847.95,1934.16,1955.59,1913.88,1933.45,1777.28,1578.11,1623.71,1476.15,1445.44,1458.93,1418.76,1570.03,1488.62,1571.05,1538.61,1530.29,1649.19,1728.1,1831.49,1869.1,1794.14,1825.79,1766.9,1921.13,1849.06,1792.38,1804.85,1823.35,1776.08,1809.64,1804.6,1783.72,1682.37,1667.9,1582.38,1586.54,1698.6,1713.01,1686.8,1816.69,1841.01,1917.99,1967.96,2134.55,2008.59,2075.94,2106.41,2111.53,1961.46,2079.92,2066.93,2133.79,2151.42,2137.81,2299.93,2431.56,2514.22,2423.18,2318.33,2237.17,2160.63,2332.14,2360.81,2401.1,2367.31,2215.93,2316.48,2533.12,2665.24,2746.54,2757.36,2772. ...

# %% [markdown]
# ## Daily Percentage Change

# %%
line = px.line(data_frame=eth_data,
               x = "Date" ,
               y="Change %", 
               title = 'Ethereum(ETH) Daily Percentage Change(2019-Present)')

line.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

line.update_yaxes(title_text = 'Perctange Change', ticksuffix = '%')
line.update_layout(showlegend = True,
    title = {
        'text': 'Ethereum(ETH) Daily Percentage Change(2019-Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

line.show()
# Out:
# <div>                            <div id="1218653b-5965-4e69-806a-e60d579af8ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1218653b-5965-4e69-806a-e60d579af8ea")) {                    Plotly.newPlot(                        "1218653b-5965-4e69-806a-e60d579af8ea",                        [{"hovertemplate":"Date=%{x}<br>Change %=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05- ...

# %% [markdown]
# # Analysis of all TOP 50 cryptocurrencies

# %% [markdown]
# **The analysis is done for each day starting from January  2021 to July 2021 on all the 50 cryptocurrencies in this dataset.**

# %%
data = pd.read_csv("../input/top-50-cryptocurrency-historical-prices/ALL_COMBINED.csv",parse_dates=['Date'])
start = "2021-01-01"
end = "2021-07-31"
mask = (data['Date'] >= start) & (data['Date'] <= end)
data = data.loc[mask]
data.head()
# Out:
#      Currency_Name       Date   Price    Open    High    Low    Vol.  Change %
# 1039          Aave 2021-01-01   90.61   88.32   90.61  84.91  1590.0      2.59
# 1040          Aave 2021-01-02   85.81   90.61   91.80  82.53  1430.0     -5.30
# 1041          Aave 2021-01-03   93.37   85.81   94.89  81.60  4080.0      8.82
# 1042          Aave 2021-01-04  113.71   93.37  115.00  86.10  4560.0     21.78
# 1043          Aave 2021-01-05  119.51  113.75  123.80  99.00  4560.0      5.10

# %%
data.describe()
# Out:
#               Price          Open          High           Low          Vol.  \
# count   9739.000000   9739.000000   9739.000000   9739.000000  9.739000e+03
# mean    2446.883582   2445.030258   2536.536400   2338.118861  1.493436e+10
# std     9831.289143   9827.667362  10164.464976   9426.925907  2.030206e+11
# min        0.000006      0.000006      0.000006      0.000006  0.000000e+00
# 25%        1.000200      1.000200      1.001670      0.999352  2.308600e+05
# 50%       16.021000     15.937000     16.865000     15.107000  3.620000e+06
# 75%      177.417000    176.910000    185.117000    166.412500  1.425950e+08
# max    63545.110000  63544.200000  64831.500000  62067.500000  8.574631e+12
#
#           Change %
# count  9739.000000
# mean      0.836337
# std       9.467182
# min     -42.810000
# 25%      -3.320000
# 50%       0.030000
# 75%       4.000000
# max     387.360000

# %% [markdown]
# ## Area Plot Change of all 50 Cryptocurrencies

# %%
area = px.area(data_frame= data , 
               x = "Date" ,
               y= "Price", 
               line_group="Currency_Name" , 
               color = "Currency_Name" , 
               color_discrete_sequence=px.colors.qualitative.Alphabet_r,
               title = 'Area Plot for TOP 50 Cryptocurrencies (2021-Present)')

area.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

area.update_yaxes(title_text = 'Price in USD', ticksuffix = '$')
area.update_layout(showlegend = True,
    title = {
        'text': 'Area Plot for TOP 50 Cryptocurrencies (Jan 2021-Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

area.show()
# Out:
# <div>                            <div id="f45331d9-5f63-44e3-b92a-3ea14344a3ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f45331d9-5f63-44e3-b92a-3ea14344a3ef")) {                    Plotly.newPlot(                        "f45331d9-5f63-44e3-b92a-3ea14344a3ef",                        [{"hovertemplate":"Currency_Name=Aave<br>Date=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"Aave","line":{"color":"#FA0087"},"mode":"lines","name":"Aave","orientation":"v","showlegend":true,"stackgroup":"1","type":"scatter","x":["2021-01-01T00:00:00","2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-17T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-24T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-01-30T00:00:00","2021-01-31T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-06T00:00:00","2021-02-07T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-13T00:00:00","2021-02-14T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-20T00:00:00","2021-02-21T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-02-27T00:00:00","2021-02-28T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-06T00:00:00","2021-03-07T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-13T00:00:00","2021-03-14T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-20T00:00:00","2021-03-21T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-27T00:00:00","2021-03-28T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-03T00:00:00","2021-04-04T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-10T00:00:00","2021-04-11T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-17T00:00:00","2021-04-18T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-24T00:00:00","2021-04-25T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-15T00:00:00","2021-05-16T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-22T00:00:00","2021-05-23T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","20 ...

# %% [markdown]
# ## Daily Percentage Change of all 50 Cryptocurrencies

# %%
area = px.area(data_frame = data,
                 y  = "Change %" , 
                 x = "Date" , 
                 line_group="Currency_Name", 
                 color = "Currency_Name",
                 color_discrete_sequence=px.colors.qualitative.Alphabet, 
                 title = 'Daily Percentage Change of all 50 Cryptocurrencies(JAN 2021- Present)')

area.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

area.update_yaxes(title_text = 'Percentage Change ', ticksuffix = '%')
area.update_layout(showlegend = True,
    title = {
        'text': 'Daily Percentage Change of all 50 Cryptocurrencies(JAN 2021- Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

area.show()
# Out:
# <div>                            <div id="07144311-1830-4604-bd49-58c9b08b2a19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07144311-1830-4604-bd49-58c9b08b2a19")) {                    Plotly.newPlot(                        "07144311-1830-4604-bd49-58c9b08b2a19",                        [{"hovertemplate":"Currency_Name=Aave<br>Date=%{x}<br>Change %=%{y}<extra></extra>","legendgroup":"Aave","line":{"color":"#AA0DFE"},"mode":"lines","name":"Aave","orientation":"v","showlegend":true,"stackgroup":"1","type":"scatter","x":["2021-01-01T00:00:00","2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-17T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-24T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-01-30T00:00:00","2021-01-31T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-06T00:00:00","2021-02-07T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-13T00:00:00","2021-02-14T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-20T00:00:00","2021-02-21T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-02-27T00:00:00","2021-02-28T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-06T00:00:00","2021-03-07T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-13T00:00:00","2021-03-14T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-20T00:00:00","2021-03-21T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-27T00:00:00","2021-03-28T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-03T00:00:00","2021-04-04T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-10T00:00:00","2021-04-11T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-17T00:00:00","2021-04-18T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-24T00:00:00","2021-04-25T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-15T00:00:00","2021-05-16T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-22T00:00:00","2021-05-23T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00", ...

# %% [markdown]
# # <center>If you find this notebook useful, support with an upvote👍</center>
